# %% [markdown]
# # 06 · Initial YOLO vs DETR Comparison (plan §8.7) — OWNER: Vinh
#
# **TODO (Vinh).** Collect both metrics JSONs into the initial comparison table.
#
# Implement `src/evaluation/compare_models.py` (currently a stub), then run it here. Writes `results/tables/comparison.csv`. See `TODO.md`.

# %%
# Make the repo importable. On Colab, set TSD_REPO_ROOT to the Drive path first.
import os, sys
REPO = os.environ.get('TSD_REPO_ROOT', os.path.abspath('..'))
os.environ['TSD_REPO_ROOT'] = REPO
if REPO not in sys.path:
    sys.path.insert(0, REPO)
print('repo root:', REPO)

# %%
# TODO (Vinh): implement src/evaluation/compare_models.py then run it here.
# from src.evaluation.compare_models import compare
# from src.utils.paths import RESULTS_TABLES, ensure_dir
# df = compare(); ensure_dir(RESULTS_TABLES); df.to_csv(RESULTS_TABLES / 'comparison.csv', index=False); df
