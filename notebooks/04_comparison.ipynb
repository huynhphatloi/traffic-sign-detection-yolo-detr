# %% [markdown]
# # 04 · Accuracy vs Speed Comparison
#
# The heart of the project: merge all metrics in `results/metrics/` into one table + an accuracy-vs-FPS chart.

# %%
# Setup: find the project root (works in Colab or locally) and make `src` importable.
import os, sys
for _p in ['/content/traffic-sign-detection-yolo-detr', os.getcwd(), '..', '../..']:
    if os.path.isdir(os.path.join(_p, 'src')):
        os.chdir(_p); break
sys.path.insert(0, os.getcwd())
print('project root:', os.getcwd())

# %%
# !python -m src.evaluation.compare_models --metrics-dir results/metrics --out results/plots

# %%
import pandas as pd
pd.read_csv('results/metrics/comparison.csv')

# %%
from IPython.display import Image
Image('results/plots/accuracy_vs_speed.png')

# %% [markdown]
# ### Conclusion
# Which model wins for **real-time self-driving** use (accuracy vs FPS vs size)? YOLO is typically the deployment model; DETR is the research comparison.
